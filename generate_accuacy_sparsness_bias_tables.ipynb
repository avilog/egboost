# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = False

import ast
        
model_name_dict = {"EGB_XGB_GA2M_CYCLIC_CYCLIC":"EG$^2$B",
                  "EGB_XGB_GA2M_CYCLIC_BEST_FIT":"EG$^2$B-BF$^2$",
                  "EGB_XGB_GA2M_BEST_FIT_BEST_FIT":"EG$^2$B-BF",
                  "EBM_GA2M":"EB$^2$M",
                  "XGB":"XGBoost",
                  "EGB_XGB_GAM_CYCLIC_CYCLIC":"EGB",
                  "EGB_XGB_GAM_BEST_FIT_BEST_FIT":"EGB-BF",
                   "EBM_GAM":"EBM",
                  "Spline":"Spline",
                  }
METHODS_LIST=model_name_dict.keys()

def extract_mean(s):
    if isinstance(s, float):
        return s

    if isinstance(s, str):
        if '±' in s:
            s = s[:s.index('±')]
        return float(s)

    raise Exception('the input is wierd: %s' % str(s))
    
def rank(x, is_metric_higher_better=True):
    x = x.apply(extract_mean)
    return x.rank(method='average', ascending=(not is_metric_higher_better), na_option='bottom')

def normalized_score(x, is_metric_higher_better=True, min_value=None):
    x = x.apply(extract_mean)
    if min_value is None:
        min_value = x.min()

    score = (x - min_value) / (x.max() - min_value)
    if not is_metric_higher_better:
        score = 1. - score
    return score

def add_new_row(table, series, row_name):
    new_indexes = list(table.index) + [row_name]
    new_table = table.append(series, ignore_index=True)
    new_table.index = new_indexes
    return new_table

def highlight_min_max(x):
    x = x.apply(extract_mean)
    return ['background-color: #cd4f39' if v == np.nanmax(x) else ('background-color: lightgreen' if v == np.nanmin(x) else '') for v in x]

def cal_statistics(table, metric, is_metric_higher_better):
    # Add two rows
    mean_score = table.apply(lambda x: x.apply(lambda s: float(s[:s.index('±')] if isinstance(s, str) and '±' in s else s)).mean(), axis=0)
    new_table = add_new_row(table, mean_score.apply(lambda x: '%.4f' % x), 'average')
    
    average_rank = mean_score.rank(ascending=(not is_metric_higher_better))
    new_table = add_new_row(new_table, average_rank, 'average_rank')

    mean_rank = table.apply(rank, axis=1, is_metric_higher_better=is_metric_higher_better).mean()
    new_table = add_new_row(new_table, mean_rank.apply(lambda x: '%.2f' % x), 'avg_rank')
    
    avg_rank_rank = mean_rank.rank(ascending=True)
    new_table = add_new_row(new_table, avg_rank_rank, 'avg_rank_rank')

    normalized_score_ = table.apply(normalized_score, axis=1, is_metric_higher_better=is_metric_higher_better)
    #display(normalized_score_)
    mean_normalized_score = normalized_score_.mean()

    new_table = add_new_row(new_table, mean_normalized_score.apply(lambda x: '%.3f' % x), 'avg_score')
    avg_score_rank = mean_normalized_score.rank(ascending=False)
    new_table = add_new_row(new_table, avg_score_rank, 'avg_score_rank')
    
    if 'auc' in metric:
        mean_normalized_score_b = table.apply(normalized_score, axis=1, min_value=0.5, is_metric_higher_better=is_metric_higher_better).mean()
        new_table = add_new_row(new_table, mean_normalized_score_b.apply(lambda x: '%.3f' % x), 'avg_score_b0.5')

        avg_score_rank_b = mean_normalized_score_b.rank(ascending=False)
        new_table = add_new_row(new_table, avg_score_rank_b, 'avg_score_b0.5_rank')

    return new_table

def model_filter(table, par, val, and_=False):

    if1 = table['model_name'].str.contains("%s=%s" %(par, val))
    if2 = ~table['model_name'].str.contains("%s=" % (par))
    if and_:
        return table[if1]
    else:
        return table[if1 | if2]

def print_latex_old(table, datasets, methods=METHODS_LIST):
            
    print("{c |"+" c"*(4)+"|"+" c"*(4)+"|c}")
    print("\hline")
    print('&  \multicolumn{4}{c}{GAM}&\multicolumn{4}{c}{GA$^2$M}&')
    print('\\\ ')
    print("Dataset"+'&')
    print("& ".join([model_name_dict[method] for method in methods]))
    print('\\\ \hline')
        
    for dataset in datasets+["avg_rank", "average"]:
        try:
            row = table.loc[dataset.lower()] 
        except :
            continue
        if dataset=="California housing":
            dataset="Housing"
        if dataset=="avg_rank":
            dataset="Rank"
        if dataset=="avg_score":
            dataset="NS"
        print(dataset+'&')
        #\textbf{bold}
        scores = row.apply(extract_mean)
        if dataset == "Rank":
            max_score_method = scores.min()
        else:
            max_score_method = scores.max()
        max_methods = scores[scores==max_score_method].index.values
        #display(max_methods)
        line = ""
        

        
        for method in METHODS_LIST:
            if method not in row:
                continue
            value = str(row[method])
            value = value.replace("-", "")
            if value[0] == "0":
                value = value[1:]
            value = value.replace("±0.", "±.")
            if method in max_methods:
                value = "\\textbf{%s}" % value
            line+=value
            line+='&'
        print(line[:-1])
        if dataset in ['Student']:
            print('\\\ \hline')
        else:
            print('\\\ ')

def print_latex(table, datasets, methods=METHODS_LIST):


    datasets += ["avg_rank"]
    dic_datasets = {data_set:data_set for data_set in datasets}
    dic_datasets["California housing"] = "Housing"

    dic_datasets["avg_rank"] = "Rank"
    dic_datasets["avg_score"] = "NS"

    print("{c c |"+" c"*(len(datasets))+"}")
    print("\hline")
    #print("Model"+'& \\rotatebox[origin=c]{45\}{')
    #print("\}& \rotatebox[origin=c]{45\}{".join([dic_datasets[dataset] for dataset in datasets]))
    print("& Model"+'& \\')
    print("& ".join([dic_datasets[dataset] for dataset in datasets]))
    print('\\\ \hline')
    display(table.head())
    for method in methods:
        #display(max_methods)
        line = ""
        if model_name_dict[method] == "EGB":
                print("\\multirow{4}{*}{\\rotatebox[origin=c]{90}{GAM}}")
        elif model_name_dict[method] == "EG$^2$B":
                print("\\multirow{4}{*}{\\rotatebox[origin=c]{90}{GA$^2$M}}")
                     
        print('&'+model_name_dict[method]+'&')
        for dataset in datasets:
            try:
                row = table.loc[dataset.lower()] 
            except :
                continue
            #\textbf{bold}
            scores = row.apply(extract_mean)
            if dataset == "avg_rank":
                max_score_method = scores.min()
            else:
                max_score_method = scores.max()
            max_methods = scores[scores==max_score_method].index.values

            if method not in row:
                continue
            value = str(row[method])
            value = value.replace("-", "")
            if value[0] == "0":
                value = value[1:]
            value = value.replace("±0.", "±.")
            if method in max_methods:
                value = "\\textbf{%s}" % value
            line+=value
            line+='&'
        print(line[:-1])
        if model_name_dict[method] in ["EGB-BF", "EG$^2$B-BF"]:
            print('\\\ \hline')
        else:
            print('\\\ ')

def display_metric(results, metric = 'test_score', limit_dig_m = 1, limit_dig_s = 2, 
                   flag_latex=True, split_reg_class=True, latex_datasets_head=True, methods=METHODS_LIST):
    results = results[results["model_name"].isin(methods)]

    datasets_class = ["Adult", "Churn", "COMPAS",  "Support2", 'breast']#
    datasets_reg = ["Bike", "California housing", "Wine",  'crimes', "fico"]#"Concrete",
    datasets_types = ["both"]
    if split_reg_class:
        datasets_types = ["class", "reg"]
    for class_reg in datasets_types:
        #display(class_reg)
        datasets = datasets_reg.copy()
        limit_dig_m = 3
        limit_dig_s = 2

        if class_reg == "both":
            datasets = datasets_class + datasets_reg
            limit_dig_s = 2
        elif class_reg == "class":
            datasets = datasets_class
            limit_dig_m = 3
            limit_dig_s = 2
            
        table = results.copy()

        table['d_name'] = table['d_name'].replace("compass", "compas").str.lower()
        
        table = table[table['d_name'].isin([dataset.lower() for dataset in datasets])]
        
        table = model_filter(table, 'l2', "0,4")

        format_m = lambda x: ('{0:.'+str(limit_dig_m)+'f}').format(x)
        format_s = lambda x: ('{0:.'+str(limit_dig_s)+'f}').format(x)

        if metric+'_std' in table.columns:
            table.loc[:, metric+"_+std"] = table[metric+'_mean'].round(limit_dig_m).apply(format_m)+\
            "±"+table[metric+'_std'].round(limit_dig_m).apply(format_s)
        else:
            table[metric+"_+std"] = table[metric].round(limit_dig_m).apply(format_m)
        #display(table[['d_name', 'model_name', metric+"_+std"]].head())


        table = pd.pivot_table(table[['d_name', 'model_name', metric+"_+std"]], aggfunc=lambda x: ' '.join(x),
                               index='d_name', columns=['model_name'])[metric+"_+std"]#.dropna(axis=1)

        table = cal_statistics(table, '', is_metric_higher_better=True)
        table = table.sort_values(by ='avg_rank', axis=1)
        pd.options.display.float_format = '{:,.3f}'.format
        display(table.style.apply(highlight_min_max, axis=1))
        if flag_latex:
            if  latex_datasets_head:
                print_latex(table, datasets=datasets.copy(), methods=methods)
            else:
                print_latex_old(table, datasets=datasets.copy(), methods=methods)

    return table



accuracy_results = pd.read_csv("accuracy_results.csv")


#accuracy_results_stats = display_metric(accuracy_results, metric = 'test_score', split_reg_class=True, 
#                                        latex_datasets_head=True, flag_latex=False, methods=METHODS_LIST)

accuracy_results_stats = display_metric(accuracy_results, metric = 'test_score', split_reg_class=True, 
                                        latex_datasets_head=True, flag_latex=False, methods=METHODS_LIST)

accuracy_results_stats = display_metric(accuracy_results, metric = 'test_score', split_reg_class=False, 
                                        latex_datasets_head=True, flag_latex=False, methods=METHODS_LIST)
summarry_accuarcy = accuracy_results_stats.loc["avg_rank", :].reset_index()
summarry_accuarcy.loc[:, "exp"] = "accuracy"
display(summarry_accuarcy)
# Out:
# <style  type="text/css" >
# #T_1dec6_row0_col0,#T_1dec6_row0_col3,#T_1dec6_row1_col2,#T_1dec6_row1_col3,#T_1dec6_row1_col4,#T_1dec6_row1_col5,#T_1dec6_row2_col8,#T_1dec6_row3_col1,#T_1dec6_row3_col6,#T_1dec6_row4_col0,#T_1dec6_row5_col0,#T_1dec6_row6_col5,#T_1dec6_row6_col6,#T_1dec6_row7_col7,#T_1dec6_row7_col8,#T_1dec6_row8_col7,#T_1dec6_row8_col8,#T_1dec6_row9_col0,#T_1dec6_row10_col8{
#             background-color:  #cd4f39;
#         }#T_1dec6_row0_col8,#T_1dec6_row1_col8,#T_1dec6_row2_col3,#T_1dec6_row3_col3,#T_1dec6_row4_col8,#T_1dec6_row5_col5,#T_1dec6_row5_col6,#T_1dec6_row6_col0,#T_1dec6_row7_col0,#T_1dec6_row8_col0,#T_1dec6_row9_col8,#T_1dec6_row10_col0{
#             background-color:  lightgreen;
#         }</style><table id="T_1dec6_" ><thead>    <tr>        <th class="index_name level0" >model_name</th>        <th class="col_heading level0 col0" >EBM_GA2M</th>        <th class="col_heading level0 col1" >EGB_XGB_GAM_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col2" >EGB_XGB_GAM_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col3" >XGB</th>        <th class="col_heading level0 col4" >EGB_XGB_GA2M_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col5" >EGB_XGB_GA2M_CYCLIC_BEST_FIT</th>        <th class="col_heading level0 col6" >EGB_XGB_GA2M_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col7" >EBM_GAM</th>        <th class="col_heading level0 col8" >Spline</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1dec6_level0_row0" class="row_heading level0 row0" >adult</th>
#                         <td id="T_1dec6_row0_col0" class="data row0 col0" >0.931±0.00</td>
#                         <td id="T_1dec6_row0_col1" class="data row0 col1" >0.929±0.00</td>
#                         <td id="T_1dec6_row0_col2" class="data row0 col2" >0.930±0.00</td>
#                         <td id="T_1dec6_row0_col3" class="data row0 col3" >0.931±0.00</td>
#                         <td id="T_1dec6_row0_col4" class="data row0 col4" >nan</td>
#                         <td id="T_1dec6_row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_1dec6_row0_col6" class="data row0 col6" >nan</td>
#                         <td id="T_1dec6_row0_col7" class="data row0 col7" >0.930±0.00</td>
#                         <td id="T_1dec6_row0_col8" class="data row0 col8" >0.921±0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_1dec6_level0_row1" class="row_heading level0 row1" >breast</th>
#                         <td id="T_1dec6_row1_col0" class="data row1 col0" >0.993±0.01</td>
#                         <td id="T_1dec6_row1_col1" class="data row1 col1" >0.992±0.01</td>
#                         <td id="T_1dec6_row1_col2" class="data row1 col2" >0.994±0.01</td>
#                         <td id="T_1dec6_row1_col3" class="data row1 col3" >0.994±0.01</td>
#                         <td id="T_1dec6_row1_col4" class="data row1 col4" >0.994±0.01</td>
#                         <td id="T_1dec6_row1_col5" class="data row1 col5" >0.994±0.01</td>
#                         <td id="T_1dec6_row1_col6" class="data row1 col6" >0.992±0.01</td>
#                         <td id="T_1dec6_row1_col7" class="data row1 col7" >0.993±0.01</td>
#                         <td id="T_1dec6_row1_col8" class="data row1 col8" >0.983±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1dec6_level0_row2" class="row_heading level0 row2" >churn</th>
#                         <td id="T_1dec6_row2_col0" class="data row2 col0" >0.843±0.01</td>
#                         <td id="T_1dec6_row2_col1" class="data row2 col1" >0.844±0.01</td>
#                         <td id="T_1dec6_row2_col2" class="data row2 col2" >0.843±0.01</td>
#                         <td id="T_1dec6_row2_col3" class="data row2 col3" >0.833±0.01</td>
#                         <td id="T_1dec6_row2_col4" class="data row2 col4" >nan</td>
#                         <td id="T_1dec6_row2_col5" class="data row2 col5" >nan</td>
#                         <td id="T_1dec6_row2_col6" class="data row2 col6" >nan</td>
#                         <td id="T_1dec6_row2_col7" class="data row2 col7" >0.842±0.01</td>
#                         <td id="T_1dec6_row2_col8" class="data row2 col8" >0.845±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1dec6_level0_row3" class="row_heading level0 row3" >compas</th>
#                         <td id="T_1dec6_row3_col0" class="data row3 col0" >0.745±0.01</td>
#                         <td id="T_1dec6_row3_col1" class="data row3 col1" >0.746±0.01</td>
#                         <td id="T_1dec6_row3_col2" class="data row3 col2" >0.744±0.01</td>
#                         <td id="T_1dec6_row3_col3" class="data row3 col3" >0.738±0.01</td>
#                         <td id="T_1dec6_row3_col4" class="data row3 col4" >0.745±0.01</td>
#                         <td id="T_1dec6_row3_col5" class="data row3 col5" >0.745±0.01</td>
#                         <td id="T_1dec6_row3_col6" class="data row3 col6" >0.746±0.01</td>
#                         <td id="T_1dec6_row3_col7" class="data row3 col7" >0.743±0.01</td>
#                         <td id="T_1dec6_row3_col8" class="data row3 col8" >0.745±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1dec6_level0_row4" class="row_heading level0 row4" >support2</th>
#                         <td id="T_1dec6_row4_col0" class="data row4 col0" >0.827±0.01</td>
#                         <td id="T_1dec6_row4_col1" class="data row4 col1" >0.820±0.01</td>
#                         <td id="T_1dec6_row4_col2" class="data row4 col2" >0.818±0.01</td>
#                         <td id="T_1dec6_row4_col3" class="data row4 col3" >0.821±0.01</td>
#                         <td id="T_1dec6_row4_col4" class="data row4 col4" >0.824±0.02</td>
#                         <td id="T_1dec6_row4_col5" class="data row4 col5" >0.823±0.02</td>
#                         <td id="T_1dec6_row4_col6" class="data row4 col6" >0.824±0.02</td>
#                         <td id="T_1dec6_row4_col7" class="data row4 col7" >0.818±0.02</td>
#                         <td id="T_1dec6_row4_col8" class="data row4 col8" >0.817±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_1dec6_level0_row5" class="row_heading level0 row5" >average</th>
#                         <td id="T_1dec6_row5_col0" class="data row5 col0" >0.8678</td>
#                         <td id="T_1dec6_row5_col1" class="data row5 col1" >0.8662</td>
#                         <td id="T_1dec6_row5_col2" class="data row5 col2" >0.8658</td>
#                         <td id="T_1dec6_row5_col3" class="data row5 col3" >0.8634</td>
#                         <td id="T_1dec6_row5_col4" class="data row5 col4" >0.8543</td>
#                         <td id="T_1dec6_row5_col5" class="data row5 col5" >0.8540</td>
#                         <td id="T_1dec6_row5_col6" class="data row5 col6" >0.8540</td>
#                         <td id="T_1dec6_row5_col7" class="data row5 col7" >0.8652</td>
#                         <td id="T_1dec6_row5_col8" class="data row5 col8" >0.8622</td>
#             </tr>
#             <tr>
#                         <th id="T_1dec6_level0_row6" class="row_heading level0 row6" >average_rank</th>
#                         <td id="T_1dec6_row6_col0" class="data row6 col0" >1.000000</td>
#                         <td id="T_1dec6_row6_col1" class="data row6 col1" >2.000000</td>
#                         <td id="T_1dec6_row6_col2" class="data row6 col2" >3.000000</td>
#                         <td id="T_1dec6_row6_col3" class="data row6 col3" >5.000000</td>
#                         <td id="T_1dec6_row6_col4" class="data row6 col4" >7.000000</td>
#                         <td id="T_1dec6_row6_col5" class="data row6 col5" >8.500000</td>
#                         <td id="T_1dec6_row6_col6" class="data row6 col6" >8.500000</td>
#                         <td id="T_1dec6_row6_col7" class="data row6 col7" >4.000000</td>
#                         <td id="T_1dec6_row6_col8" class="data row6 col8
# <style  type="text/css" >
# #T_41f75_row0_col0,#T_41f75_row1_col0,#T_41f75_row2_col2,#T_41f75_row2_col3,#T_41f75_row3_col0,#T_41f75_row4_col0,#T_41f75_row5_col3,#T_41f75_row5_col4,#T_41f75_row6_col8,#T_41f75_row7_col8,#T_41f75_row8_col8,#T_41f75_row9_col3,#T_41f75_row10_col8{
#             background-color:  #cd4f39;
#         }#T_41f75_row0_col7,#T_41f75_row1_col8,#T_41f75_row2_col8,#T_41f75_row3_col7,#T_41f75_row4_col8,#T_41f75_row5_col8,#T_41f75_row6_col3,#T_41f75_row6_col4,#T_41f75_row7_col0,#T_41f75_row8_col0,#T_41f75_row9_col8,#T_41f75_row10_col3{
#             background-color:  lightgreen;
#         }</style><table id="T_41f75_" ><thead>    <tr>        <th class="index_name level0" >model_name</th>        <th class="col_heading level0 col0" >XGB</th>        <th class="col_heading level0 col1" >EBM_GA2M</th>        <th class="col_heading level0 col2" >EGB_XGB_GAM_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col3" >EGB_XGB_GA2M_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col4" >EGB_XGB_GA2M_CYCLIC_BEST_FIT</th>        <th class="col_heading level0 col5" >EGB_XGB_GA2M_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col6" >EGB_XGB_GAM_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col7" >EBM_GAM</th>        <th class="col_heading level0 col8" >Spline</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_41f75_level0_row0" class="row_heading level0 row0" >bike</th>
#                         <td id="T_41f75_row0_col0" class="data row0 col0" >-39.389±1.87</td>
#                         <td id="T_41f75_row0_col1" class="data row0 col1" >-50.763±1.36</td>
#                         <td id="T_41f75_row0_col2" class="data row0 col2" >-97.506±1.22</td>
#                         <td id="T_41f75_row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_41f75_row0_col4" class="data row0 col4" >nan</td>
#                         <td id="T_41f75_row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_41f75_row0_col6" class="data row0 col6" >-97.557±1.21</td>
#                         <td id="T_41f75_row0_col7" class="data row0 col7" >-97.627±1.17</td>
#                         <td id="T_41f75_row0_col8" class="data row0 col8" >-97.617±1.26</td>
#             </tr>
#             <tr>
#                         <th id="T_41f75_level0_row1" class="row_heading level0 row1" >california housing</th>
#                         <td id="T_41f75_row1_col0" class="data row1 col0" >-0.465±0.01</td>
#                         <td id="T_41f75_row1_col1" class="data row1 col1" >-0.504±0.01</td>
#                         <td id="T_41f75_row1_col2" class="data row1 col2" >-0.567±0.01</td>
#                         <td id="T_41f75_row1_col3" class="data row1 col3" >-0.493±0.01</td>
#                         <td id="T_41f75_row1_col4" class="data row1 col4" >-0.496±0.01</td>
#                         <td id="T_41f75_row1_col5" class="data row1 col5" >-0.500±0.01</td>
#                         <td id="T_41f75_row1_col6" class="data row1 col6" >-0.571±0.01</td>
#                         <td id="T_41f75_row1_col7" class="data row1 col7" >-0.568±0.01</td>
#                         <td id="T_41f75_row1_col8" class="data row1 col8" >-0.599±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_41f75_level0_row2" class="row_heading level0 row2" >crimes</th>
#                         <td id="T_41f75_row2_col0" class="data row2 col0" >-0.140±0.00</td>
#                         <td id="T_41f75_row2_col1" class="data row2 col1" >-0.137±0.01</td>
#                         <td id="T_41f75_row2_col2" class="data row2 col2" >-0.134±0.01</td>
#                         <td id="T_41f75_row2_col3" class="data row2 col3" >-0.134±0.01</td>
#                         <td id="T_41f75_row2_col4" class="data row2 col4" >-0.135±0.01</td>
#                         <td id="T_41f75_row2_col5" class="data row2 col5" >-0.136±0.01</td>
#                         <td id="T_41f75_row2_col6" class="data row2 col6" >-0.136±0.01</td>
#                         <td id="T_41f75_row2_col7" class="data row2 col7" >-0.137±0.01</td>
#                         <td id="T_41f75_row2_col8" class="data row2 col8" >-0.145±0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_41f75_level0_row3" class="row_heading level0 row3" >fico</th>
#                         <td id="T_41f75_row3_col0" class="data row3 col0" >-3.219±0.05</td>
#                         <td id="T_41f75_row3_col1" class="data row3 col1" >-3.250±0.08</td>
#                         <td id="T_41f75_row3_col2" class="data row3 col2" >-3.500±0.10</td>
#                         <td id="T_41f75_row3_col3" class="data row3 col3" >-3.245±0.10</td>
#                         <td id="T_41f75_row3_col4" class="data row3 col4" >-3.241±0.06</td>
#                         <td id="T_41f75_row3_col5" class="data row3 col5" >-3.240±0.08</td>
#                         <td id="T_41f75_row3_col6" class="data row3 col6" >-3.511±0.09</td>
#                         <td id="T_41f75_row3_col7" class="data row3 col7" >-3.512±0.09</td>
#                         <td id="T_41f75_row3_col8" class="data row3 col8" >-3.509±0.09</td>
#             </tr>
#             <tr>
#                         <th id="T_41f75_level0_row4" class="row_heading level0 row4" >wine</th>
#                         <td id="T_41f75_row4_col0" class="data row4 col0" >-0.652±0.01</td>
#                         <td id="T_41f75_row4_col1" class="data row4 col1" >-0.690±0.01</td>
#                         <td id="T_41f75_row4_col2" class="data row4 col2" >-0.711±0.01</td>
#                         <td id="T_41f75_row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_41f75_row4_col4" class="data row4 col4" >nan</td>
#                         <td id="T_41f75_row4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_41f75_row4_col6" class="data row4 col6" >-0.709±0.01</td>
#                         <td id="T_41f75_row4_col7" class="data row4 col7" >-0.712±0.01</td>
#                         <td id="T_41f75_row4_col8" class="data row4 col8" >-0.744±0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_41f75_level0_row5" class="row_heading level0 row5" >average</th>
#                         <td id="T_41f75_row5_col0" class="data row5 col0" >-8.7730</td>
#                         <td id="T_41f75_row5_col1" class="data row5 col1" >-11.0688</td>
#                         <td id="T_41f75_row5_col2" class="data row5 col2" >-20.4836</td>
#                         <td id="T_41f75_row5_col3" class="data row5 col3" >-1.2907</td>
#                         <td id="T_41f75_row5_col4" class="data row5 col4" >-1.2907</td>
#                         <td id="T_41f75_row5_col5" class="data row5 col5" >-1.2920</td>
#                         <td id="T_41f75_row5_col6" class="data row5 col6" >-20.4968</td>
#                         <td id="T_41f75_row5_col7" class="data row5 col7" >-20.5112</td>
#                         <td id="T_41f75_row5_col8" class="data row5 col8" >-20.5228</td>
#             </tr>
#             <tr>
#                         <th id="T_41f75_level0_row6" class="row_heading level0 row6" >average_rank</th>
#                         <td id="T_41f75_row6_col0" class="data row6 col0" >4.000000</td>
#                         <td id="T_41f75_row6_col1" class="data row6 col1" >5.000000</td>
#                         <td id="T_41f75_row6_col2" class="data row6 col2" >6.000000</td>
#                         <td id="T_41f75_row6_col3" class="data row6 col3" >1.500000</td>
#                         <td id="T_41f75_row6_col4" class="data row6 col4" >1.500000</td>
#                         <td id="T_41f75_row6_col5" class="data row6 col5" >3.000000</td>
#                         <td id="T_41f75_row6_col6" class="data row6 col6" >7.000000</td>
#                         <td id="T_41f75_row6_col7" class="data row6 col7" >8.000000</td>
#                         <td id="T_41f75_row6_col8" class="data row6 col8" >9.000000</td>
#             </tr>
#             <t
# <style  type="text/css" >
# #T_aa534_row0_col0,#T_aa534_row0_col1,#T_aa534_row1_col0,#T_aa534_row2_col0,#T_aa534_row2_col4,#T_aa534_row2_col5,#T_aa534_row2_col6,#T_aa534_row3_col0,#T_aa534_row4_col8,#T_aa534_row5_col2,#T_aa534_row5_col3,#T_aa534_row6_col2,#T_aa534_row6_col3,#T_aa534_row7_col0,#T_aa534_row8_col1,#T_aa534_row9_col0,#T_aa534_row10_col3,#T_aa534_row10_col5,#T_aa534_row11_col8,#T_aa534_row12_col8,#T_aa534_row13_col8,#T_aa534_row14_col3,#T_aa534_row15_col8{
#             background-color:  #cd4f39;
#         }#T_aa534_row0_col8,#T_aa534_row1_col7,#T_aa534_row2_col8,#T_aa534_row3_col8,#T_aa534_row4_col0,#T_aa534_row5_col0,#T_aa534_row6_col8,#T_aa534_row7_col7,#T_aa534_row8_col8,#T_aa534_row9_col8,#T_aa534_row10_col8,#T_aa534_row11_col3,#T_aa534_row11_col5,#T_aa534_row12_col0,#T_aa534_row13_col0,#T_aa534_row14_col8,#T_aa534_row15_col3{
#             background-color:  lightgreen;
#         }</style><table id="T_aa534_" ><thead>    <tr>        <th class="index_name level0" >model_name</th>        <th class="col_heading level0 col0" >XGB</th>        <th class="col_heading level0 col1" >EBM_GA2M</th>        <th class="col_heading level0 col2" >EGB_XGB_GAM_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col3" >EGB_XGB_GA2M_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col4" >EGB_XGB_GAM_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col5" >EGB_XGB_GA2M_CYCLIC_BEST_FIT</th>        <th class="col_heading level0 col6" >EGB_XGB_GA2M_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col7" >EBM_GAM</th>        <th class="col_heading level0 col8" >Spline</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aa534_level0_row0" class="row_heading level0 row0" >adult</th>
#                         <td id="T_aa534_row0_col0" class="data row0 col0" >0.931±0.00</td>
#                         <td id="T_aa534_row0_col1" class="data row0 col1" >0.931±0.00</td>
#                         <td id="T_aa534_row0_col2" class="data row0 col2" >0.929±0.00</td>
#                         <td id="T_aa534_row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_aa534_row0_col4" class="data row0 col4" >0.930±0.00</td>
#                         <td id="T_aa534_row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_aa534_row0_col6" class="data row0 col6" >nan</td>
#                         <td id="T_aa534_row0_col7" class="data row0 col7" >0.930±0.00</td>
#                         <td id="T_aa534_row0_col8" class="data row0 col8" >0.921±0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_aa534_level0_row1" class="row_heading level0 row1" >bike</th>
#                         <td id="T_aa534_row1_col0" class="data row1 col0" >-39.389±1.87</td>
#                         <td id="T_aa534_row1_col1" class="data row1 col1" >-50.763±1.36</td>
#                         <td id="T_aa534_row1_col2" class="data row1 col2" >-97.506±1.22</td>
#                         <td id="T_aa534_row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_aa534_row1_col4" class="data row1 col4" >-97.557±1.21</td>
#                         <td id="T_aa534_row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_aa534_row1_col6" class="data row1 col6" >nan</td>
#                         <td id="T_aa534_row1_col7" class="data row1 col7" >-97.627±1.17</td>
#                         <td id="T_aa534_row1_col8" class="data row1 col8" >-97.617±1.26</td>
#             </tr>
#             <tr>
#                         <th id="T_aa534_level0_row2" class="row_heading level0 row2" >breast</th>
#                         <td id="T_aa534_row2_col0" class="data row2 col0" >0.994±0.01</td>
#                         <td id="T_aa534_row2_col1" class="data row2 col1" >0.993±0.01</td>
#                         <td id="T_aa534_row2_col2" class="data row2 col2" >0.992±0.01</td>
#                         <td id="T_aa534_row2_col3" class="data row2 col3" >0.992±0.01</td>
#                         <td id="T_aa534_row2_col4" class="data row2 col4" >0.994±0.01</td>
#                         <td id="T_aa534_row2_col5" class="data row2 col5" >0.994±0.01</td>
#                         <td id="T_aa534_row2_col6" class="data row2 col6" >0.994±0.01</td>
#                         <td id="T_aa534_row2_col7" class="data row2 col7" >0.993±0.01</td>
#                         <td id="T_aa534_row2_col8" class="data row2 col8" >0.983±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_aa534_level0_row3" class="row_heading level0 row3" >california housing</th>
#                         <td id="T_aa534_row3_col0" class="data row3 col0" >-0.465±0.01</td>
#                         <td id="T_aa534_row3_col1" class="data row3 col1" >-0.504±0.01</td>
#                         <td id="T_aa534_row3_col2" class="data row3 col2" >-0.567±0.01</td>
#                         <td id="T_aa534_row3_col3" class="data row3 col3" >-0.493±0.01</td>
#                         <td id="T_aa534_row3_col4" class="data row3 col4" >-0.571±0.01</td>
#                         <td id="T_aa534_row3_col5" class="data row3 col5" >-0.496±0.01</td>
#                         <td id="T_aa534_row3_col6" class="data row3 col6" >-0.500±0.01</td>
#                         <td id="T_aa534_row3_col7" class="data row3 col7" >-0.568±0.01</td>
#                         <td id="T_aa534_row3_col8" class="data row3 col8" >-0.599±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_aa534_level0_row4" class="row_heading level0 row4" >churn</th>
#                         <td id="T_aa534_row4_col0" class="data row4 col0" >0.833±0.01</td>
#                         <td id="T_aa534_row4_col1" class="data row4 col1" >0.843±0.01</td>
#                         <td id="T_aa534_row4_col2" class="data row4 col2" >0.844±0.01</td>
#                         <td id="T_aa534_row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_aa534_row4_col4" class="data row4 col4" >0.843±0.01</td>
#                         <td id="T_aa534_row4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_aa534_row4_col6" class="data row4 col6" >nan</td>
#                         <td id="T_aa534_row4_col7" class="data row4 col7" >0.842±0.01</td>
#                         <td id="T_aa534_row4_col8" class="data row4 col8" >0.845±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_aa534_level0_row5" class="row_heading level0 row5" >compas</th>
#                         <td id="T_aa534_row5_col0" class="data row5 col0" >0.738±0.01</td>
#                         <td id="T_aa534_row5_col1" class="data row5 col1" >0.745±0.01</td>
#                         <td id="T_aa534_row5_col2" class="data row5 col2" >0.746±0.01</td>
#                         <td id="T_aa534_row5_col3" class="data row5 col3" >0.746±0.01</td>
#                         <td id="T_aa534_row5_col4" class="data row5 col4" >0.744±0.01</td>
#                         <td id="T_aa534_row5_col5" class="data row5 col5" >0.745±0.01</td>
#                         <td id="T_aa534_row5_col6" class="data row5 col6" >0.745±0.01</td>
#                         <td id="T_aa534_row5_col7" class="data row5 col7" >0.743±0.01</td>
#                         <td id="T_aa534_row5_col8" class="data row5 col8" >0.745±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_aa534_level0_row6" class="row_heading level0 row6" >crimes</th>
#                         <td id="T_aa534_row6_col0" class="data row6 col0" >-0.140±0.00</td>
#                         <td id="T_aa534_row6_col1" class="data row6 col1" >-0.137±0.01</td>
#                         <td id="T_aa534_row6_col2" class="data row6 col2" >-0.134±0.01</td>
#                         <td id="T_aa534_row6_col3" class="data row6 col3" >-0.134±0.01</td>
#                         <td id="T_aa534_row6_col4" class="data row6 col4" >-0.136±0.01</td>
#                         <td id="T_aa534_row6_col5" class="data row6 col5" >-0.135±0.01</td>
#                        model_name avg_rank       exp
# 0                             XGB     3.60  accuracy
# 1                        EBM_GA2M     3.65  accuracy
# 2   EGB_XGB_GAM_BEST_FIT_BEST_FIT     4.25  accuracy
# 3  EGB_XGB_GA2M_BEST_FIT_BEST_FIT     5.10  accuracy
# 4       EGB_XGB_GAM_CYCLIC_CYCLIC     5.15  accuracy
# 5    EGB_XGB_GA2M_CYCLIC_BEST_FIT     5.20  accuracy
# 6      EGB_XGB_GA2M_CYCLIC_CYCLIC     5.20  accuracy
# 7                         EBM_GAM     6.30  accuracy
# 8                          Spline     6.55  accuracy

# %%
METHODS_LIST_times=[
    'EGB_XGB_GAM_CYCLIC_CYCLIC',
    'EBM_GAM',
    'Spline',
    'EGB_XGB_GA2M_CYCLIC_CYCLIC',
    'EBM_GA2M',
    'XGB'
    ]
accuracy_results['fit_time_mean'] = -1*accuracy_results['fit_time_mean']
accuracy_results_stats = display_metric(accuracy_results, metric = 'fit_time_mean', split_reg_class=False, 
                                        latex_datasets_head=False, flag_latex=False, methods=METHODS_LIST_times)
# Out:
# <style  type="text/css" >
# #T_23545_row0_col0,#T_23545_row1_col0,#T_23545_row2_col1,#T_23545_row3_col0,#T_23545_row4_col1,#T_23545_row5_col0,#T_23545_row6_col1,#T_23545_row7_col1,#T_23545_row8_col1,#T_23545_row9_col0,#T_23545_row10_col4,#T_23545_row11_col3,#T_23545_row12_col4,#T_23545_row13_col4,#T_23545_row14_col1,#T_23545_row15_col3{
#             background-color:  #cd4f39;
#         }#T_23545_row0_col3,#T_23545_row1_col3,#T_23545_row2_col3,#T_23545_row3_col3,#T_23545_row4_col3,#T_23545_row5_col3,#T_23545_row6_col3,#T_23545_row7_col3,#T_23545_row8_col3,#T_23545_row9_col3,#T_23545_row10_col3,#T_23545_row11_col4,#T_23545_row12_col0,#T_23545_row12_col1,#T_23545_row13_col0,#T_23545_row13_col1,#T_23545_row14_col3,#T_23545_row15_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_23545_" ><thead>    <tr>        <th class="index_name level0" >model_name</th>        <th class="col_heading level0 col0" >EBM_GA2M</th>        <th class="col_heading level0 col1" >Spline</th>        <th class="col_heading level0 col2" >EBM_GAM</th>        <th class="col_heading level0 col3" >XGB</th>        <th class="col_heading level0 col4" >EGB_XGB_GA2M_CYCLIC_CYCLIC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23545_level0_row0" class="row_heading level0 row0" >adult</th>
#                         <td id="T_23545_row0_col0" class="data row0 col0" >48.474</td>
#                         <td id="T_23545_row0_col1" class="data row0 col1" >47.060</td>
#                         <td id="T_23545_row0_col2" class="data row0 col2" >39.320</td>
#                         <td id="T_23545_row0_col3" class="data row0 col3" >0.554</td>
#                         <td id="T_23545_row0_col4" class="data row0 col4" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_23545_level0_row1" class="row_heading level0 row1" >bike</th>
#                         <td id="T_23545_row1_col0" class="data row1 col0" >170.401</td>
#                         <td id="T_23545_row1_col1" class="data row1 col1" >9.319</td>
#                         <td id="T_23545_row1_col2" class="data row1 col2" >14.809</td>
#                         <td id="T_23545_row1_col3" class="data row1 col3" >1.127</td>
#                         <td id="T_23545_row1_col4" class="data row1 col4" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_23545_level0_row2" class="row_heading level0 row2" >breast</th>
#                         <td id="T_23545_row2_col0" class="data row2 col0" >5.998</td>
#                         <td id="T_23545_row2_col1" class="data row2 col1" >202.841</td>
#                         <td id="T_23545_row2_col2" class="data row2 col2" >1.987</td>
#                         <td id="T_23545_row2_col3" class="data row2 col3" >0.063</td>
#                         <td id="T_23545_row2_col4" class="data row2 col4" >60.060</td>
#             </tr>
#             <tr>
#                         <th id="T_23545_level0_row3" class="row_heading level0 row3" >california housing</th>
#                         <td id="T_23545_row3_col0" class="data row3 col0" >147.442</td>
#                         <td id="T_23545_row3_col1" class="data row3 col1" >10.684</td>
#                         <td id="T_23545_row3_col2" class="data row3 col2" >25.884</td>
#                         <td id="T_23545_row3_col3" class="data row3 col3" >0.856</td>
#                         <td id="T_23545_row3_col4" class="data row3 col4" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_23545_level0_row4" class="row_heading level0 row4" >churn</th>
#                         <td id="T_23545_row4_col0" class="data row4 col0" >3.345</td>
#                         <td id="T_23545_row4_col1" class="data row4 col1" >4.155</td>
#                         <td id="T_23545_row4_col2" class="data row4 col2" >1.942</td>
#                         <td id="T_23545_row4_col3" class="data row4 col3" >0.106</td>
#                         <td id="T_23545_row4_col4" class="data row4 col4" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_23545_level0_row5" class="row_heading level0 row5" >compas</th>
#                         <td id="T_23545_row5_col0" class="data row5 col0" >2.256</td>
#                         <td id="T_23545_row5_col1" class="data row5 col1" >1.835</td>
#                         <td id="T_23545_row5_col2" class="data row5 col2" >1.525</td>
#                         <td id="T_23545_row5_col3" class="data row5 col3" >0.071</td>
#                         <td id="T_23545_row5_col4" class="data row5 col4" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_23545_level0_row6" class="row_heading level0 row6" >crimes</th>
#                         <td id="T_23545_row6_col0" class="data row6 col0" >7.999</td>
#                         <td id="T_23545_row6_col1" class="data row6 col1" >556.342</td>
#                         <td id="T_23545_row6_col2" class="data row6 col2" >1.571</td>
#                         <td id="T_23545_row6_col3" class="data row6 col3" >0.203</td>
#                         <td id="T_23545_row6_col4" class="data row6 col4" >139.256</td>
#             </tr>
#             <tr>
#                         <th id="T_23545_level0_row7" class="row_heading level0 row7" >fico</th>
#                         <td id="T_23545_row7_col0" class="data row7 col0" >13.813</td>
#                         <td id="T_23545_row7_col1" class="data row7 col1" >22.030</td>
#                         <td id="T_23545_row7_col2" class="data row7 col2" >8.359</td>
#                         <td id="T_23545_row7_col3" class="data row7 col3" >0.237</td>
#                         <td id="T_23545_row7_col4" class="data row7 col4" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_23545_level0_row8" class="row_heading level0 row8" >support2</th>
#                         <td id="T_23545_row8_col0" class="data row8 col0" >7.617</td>
#                         <td id="T_23545_row8_col1" class="data row8 col1" >74.560</td>
#                         <td id="T_23545_row8_col2" class="data row8 col2" >3.217</td>
#                         <td id="T_23545_row8_col3" class="data row8 col3" >0.174</td>
#                         <td id="T_23545_row8_col4" class="data row8 col4" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_23545_level0_row9" class="row_heading level0 row9" >wine</th>
#                         <td id="T_23545_row9_col0" class="data row9 col0" >14.685</td>
#                         <td id="T_23545_row9_col1" class="data row9 col1" >5.101</td>
#                         <td id="T_23545_row9_col2" class="data row9 col2" >1.652</td>
#                         <td id="T_23545_row9_col3" class="data row9 col3" >0.275</td>
#                         <td id="T_23545_row9_col4" class="data row9 col4" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_23545_level0_row10" class="row_heading level0 row10" >average</th>
#                         <td id="T_23545_row10_col0" class="data row10 col0" >42.2030</td>
#                         <td id="T_23545_row10_col1" class="data row10 col1" >93.3927</td>
#                         <td id="T_23545_row10_col2" class="data row10 col2" >10.0266</td>
#                         <td id="T_23545_row10_col3" class="data row10 col3" >0.3666</td>
#                         <td id="T_23545_row10_col4" class="data row10 col4" >99.6580</td>
#             </tr>
#             <tr>
#                         <th id="T_23545_level0_row11" class="row_heading level0 row11" >average_rank</th>
#                         <td id="T_23545_row11_col0" class="data row11 col0" >3.000000</td>
#                         <td id="T_23545_row11_col1" class="data row11 col1" >2.000000</td>
#                         <td id="T_23545_row11_col2" class="data row11 col2" >4.000000</td>
#                         <td id="T_23545_row11_col3" class="data row11 col3" >5.000000</td>
#                         <td id="T_23545_row11_col4" class="data row11

# %%
feature_sparsness_results = pd.read_csv("feature_sparseness_results.csv")

feature_sparsness_results_stats = display_metric(feature_sparsness_results, metric = 'area_till_zero_mean'
                                                , split_reg_class=False, latex_datasets_head=False,
                                                 flag_latex=False, methods=METHODS_LIST)

summarry_stats_sparss = feature_sparsness_results_stats.loc["avg_rank", :].reset_index()
summarry_stats_sparss.loc[:, "exp"] = "feature_sparsness"
summarry_sparss = pd.concat([summarry_accuarcy, summarry_stats_sparss])
display(summarry_sparss)


df = feature_sparsness_results[feature_sparsness_results["d_name"]=="breast"]
#df = df[df["model_name"].isin(METHODS_LIST)]
df = df[df["model_name"].isin(["EBM_GAM",  "EGB_XGB_GAM_CYCLIC_CYCLIC",  "EGB_XGB_GAM_BEST_FIT_BEST_FIT"])]

df.mean_perf = df.mean_perf.apply(ast.literal_eval)
df.std_perf = df.std_perf.apply(ast.literal_eval)

#display(df)
fig, ax = plt.subplots(figsize=(12, 8))
names_current = []
for i, results in df.iterrows():
    
    name  =  model_name_dict[results["model_name"]]
    dataset_name = results["d_name"]
    names_current += [name]
    the_mean = np.array(results["mean_perf"]).astype(float)
    the_std = results["std_perf"]
    #print(the_mean)
    #the_mean, the_std = monotonic_constrain(the_mean, the_std)      
    #print("%s num features %d error %.3f" % (name, len(the_mean), np.mean(results["error"])))
    ax.errorbar(range(len(the_mean)), the_mean, the_std, label=name)
    #ax.set_ylim(-0.05, 1.05)
ax.legend(names_current)
interactions = 16
fig.suptitle(dataset_name.capitalize(), fontsize=30)#  + (" - GA^2M" if interactions>0  else " - GAM"))
ax.set_xlabel('Number of features added')
ax.set_ylabel('Test RMSE')
plt.show()
# Out:
# <style  type="text/css" >
# #T_e43c6_row0_col0,#T_e43c6_row1_col1,#T_e43c6_row2_col1,#T_e43c6_row2_col2,#T_e43c6_row3_col7,#T_e43c6_row4_col0,#T_e43c6_row5_col1,#T_e43c6_row6_col1,#T_e43c6_row7_col0,#T_e43c6_row8_col0,#T_e43c6_row9_col0,#T_e43c6_row10_col7,#T_e43c6_row11_col6,#T_e43c6_row12_col7,#T_e43c6_row13_col7,#T_e43c6_row14_col0,#T_e43c6_row15_col6{
#             background-color:  #cd4f39;
#         }#T_e43c6_row0_col6,#T_e43c6_row1_col4,#T_e43c6_row2_col5,#T_e43c6_row3_col6,#T_e43c6_row4_col7,#T_e43c6_row5_col7,#T_e43c6_row6_col5,#T_e43c6_row6_col6,#T_e43c6_row7_col6,#T_e43c6_row8_col6,#T_e43c6_row9_col6,#T_e43c6_row10_col6,#T_e43c6_row11_col7,#T_e43c6_row12_col0,#T_e43c6_row13_col0,#T_e43c6_row14_col6,#T_e43c6_row15_col0{
#             background-color:  lightgreen;
#         }</style><table id="T_e43c6_" ><thead>    <tr>        <th class="index_name level0" >model_name</th>        <th class="col_heading level0 col0" >EBM_GA2M</th>        <th class="col_heading level0 col1" >EGB_XGB_GA2M_CYCLIC_BEST_FIT</th>        <th class="col_heading level0 col2" >EGB_XGB_GA2M_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col3" >EBM_GAM</th>        <th class="col_heading level0 col4" >EGB_XGB_GAM_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col5" >EGB_XGB_GA2M_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col6" >EGB_XGB_GAM_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col7" >Spline</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e43c6_level0_row0" class="row_heading level0 row0" >adult</th>
#                         <td id="T_e43c6_row0_col0" class="data row0 col0" >0.348</td>
#                         <td id="T_e43c6_row0_col1" class="data row0 col1" >0.336</td>
#                         <td id="T_e43c6_row0_col2" class="data row0 col2" >0.336</td>
#                         <td id="T_e43c6_row0_col3" class="data row0 col3" >0.337</td>
#                         <td id="T_e43c6_row0_col4" class="data row0 col4" >0.331</td>
#                         <td id="T_e43c6_row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_e43c6_row0_col6" class="data row0 col6" >0.324</td>
#                         <td id="T_e43c6_row0_col7" class="data row0 col7" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_e43c6_level0_row1" class="row_heading level0 row1" >bike</th>
#                         <td id="T_e43c6_row1_col0" class="data row1 col0" >0.416</td>
#                         <td id="T_e43c6_row1_col1" class="data row1 col1" >0.417</td>
#                         <td id="T_e43c6_row1_col2" class="data row1 col2" >0.407</td>
#                         <td id="T_e43c6_row1_col3" class="data row1 col3" >0.241</td>
#                         <td id="T_e43c6_row1_col4" class="data row1 col4" >0.240</td>
#                         <td id="T_e43c6_row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_e43c6_row1_col6" class="data row1 col6" >0.241</td>
#                         <td id="T_e43c6_row1_col7" class="data row1 col7" >0.314</td>
#             </tr>
#             <tr>
#                         <th id="T_e43c6_level0_row2" class="row_heading level0 row2" >breast</th>
#                         <td id="T_e43c6_row2_col0" class="data row2 col0" >0.376</td>
#                         <td id="T_e43c6_row2_col1" class="data row2 col1" >0.425</td>
#                         <td id="T_e43c6_row2_col2" class="data row2 col2" >0.425</td>
#                         <td id="T_e43c6_row2_col3" class="data row2 col3" >0.369</td>
#                         <td id="T_e43c6_row2_col4" class="data row2 col4" >0.421</td>
#                         <td id="T_e43c6_row2_col5" class="data row2 col5" >0.313</td>
#                         <td id="T_e43c6_row2_col6" class="data row2 col6" >0.316</td>
#                         <td id="T_e43c6_row2_col7" class="data row2 col7" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_e43c6_level0_row3" class="row_heading level0 row3" >california housing</th>
#                         <td id="T_e43c6_row3_col0" class="data row3 col0" >0.531</td>
#                         <td id="T_e43c6_row3_col1" class="data row3 col1" >0.498</td>
#                         <td id="T_e43c6_row3_col2" class="data row3 col2" >0.509</td>
#                         <td id="T_e43c6_row3_col3" class="data row3 col3" >0.429</td>
#                         <td id="T_e43c6_row3_col4" class="data row3 col4" >0.427</td>
#                         <td id="T_e43c6_row3_col5" class="data row3 col5" >0.505</td>
#                         <td id="T_e43c6_row3_col6" class="data row3 col6" >0.422</td>
#                         <td id="T_e43c6_row3_col7" class="data row3 col7" >0.860</td>
#             </tr>
#             <tr>
#                         <th id="T_e43c6_level0_row4" class="row_heading level0 row4" >churn</th>
#                         <td id="T_e43c6_row4_col0" class="data row4 col0" >0.315</td>
#                         <td id="T_e43c6_row4_col1" class="data row4 col1" >0.310</td>
#                         <td id="T_e43c6_row4_col2" class="data row4 col2" >0.310</td>
#                         <td id="T_e43c6_row4_col3" class="data row4 col3" >0.307</td>
#                         <td id="T_e43c6_row4_col4" class="data row4 col4" >0.311</td>
#                         <td id="T_e43c6_row4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_e43c6_row4_col6" class="data row4 col6" >0.257</td>
#                         <td id="T_e43c6_row4_col7" class="data row4 col7" >0.252</td>
#             </tr>
#             <tr>
#                         <th id="T_e43c6_level0_row5" class="row_heading level0 row5" >compas</th>
#                         <td id="T_e43c6_row5_col0" class="data row5 col0" >0.426</td>
#                         <td id="T_e43c6_row5_col1" class="data row5 col1" >0.430</td>
#                         <td id="T_e43c6_row5_col2" class="data row5 col2" >0.427</td>
#                         <td id="T_e43c6_row5_col3" class="data row5 col3" >0.408</td>
#                         <td id="T_e43c6_row5_col4" class="data row5 col4" >0.409</td>
#                         <td id="T_e43c6_row5_col5" class="data row5 col5" >0.427</td>
#                         <td id="T_e43c6_row5_col6" class="data row5 col6" >0.416</td>
#                         <td id="T_e43c6_row5_col7" class="data row5 col7" >0.349</td>
#             </tr>
#             <tr>
#                         <th id="T_e43c6_level0_row6" class="row_heading level0 row6" >crimes</th>
#                         <td id="T_e43c6_row6_col0" class="data row6 col0" >0.585</td>
#                         <td id="T_e43c6_row6_col1" class="data row6 col1" >0.592</td>
#                         <td id="T_e43c6_row6_col2" class="data row6 col2" >0.590</td>
#                         <td id="T_e43c6_row6_col3" class="data row6 col3" >0.577</td>
#                         <td id="T_e43c6_row6_col4" class="data row6 col4" >0.575</td>
#                         <td id="T_e43c6_row6_col5" class="data row6 col5" >0.244</td>
#                         <td id="T_e43c6_row6_col6" class="data row6 col6" >0.244</td>
#                         <td id="T_e43c6_row6_col7" class="data row6 col7" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_e43c6_level0_row7" class="row_heading level0 row7" >fico</th>
#                         <td id="T_e43c6_row7_col0" class="data row7 col0" >0.266</td>
#                         <td id="T_e43c6_row7_col1" class="data row7 col1" >0.264</td>
#                         <td id="T_e43c6_row7_col2" class="data row7 col2" >0.264</td>
#                         <td id="T_e43c6_row7_col3" class="data row7 col3" >0.237</td>
#                         <td id="T_e43c6_row7_col4" class="data row7 col4" >0.237</td>
#                         <td id="T_e43c6_row7_col5" class="data row7 col5" >0.222</td>
#                         <td id="T_e43c6_row7_col6" class="data row7 col6" >0.196</td>
#                         <td id="T_e43c6_row7_col7" class="data row7
#                        model_name avg_rank                exp
# 0                             XGB     3.60           accuracy
# 1                        EBM_GA2M     3.65           accuracy
# 2   EGB_XGB_GAM_BEST_FIT_BEST_FIT     4.25           accuracy
# 3  EGB_XGB_GA2M_BEST_FIT_BEST_FIT     5.10           accuracy
# 4       EGB_XGB_GAM_CYCLIC_CYCLIC     5.15           accuracy
# 5    EGB_XGB_GA2M_CYCLIC_BEST_FIT     5.20           accuracy
# 6      EGB_XGB_GA2M_CYCLIC_CYCLIC     5.20           accuracy
# 7                         EBM_GAM     6.30           accuracy
# 8                          Spline     6.55           accuracy
# 0                        EBM_GA2M     2.00  feature_sparsness
# 1    EGB_XGB_GA2M_CYCLIC_BEST_FIT     2.50  feature_sparsness
# 2      EGB_XGB_GA2M_CYCLIC_CYCLIC     2.55  feature_sparsness
# 3                         EBM_GAM     4.90  feature_sparsness
# 4       EGB_XGB_GAM_CYCLIC_CYCLIC     4.95  feature_sparsness
# 5  EGB_XGB_GA2M_BEST_FIT_BEST_FIT     6.15  feature_sparsness
# 6   EGB_XGB_GAM_BEST_FIT_BEST_FIT     6.40  feature_sparsness
# 7                          Spline     6.55  feature_sparsness

# %%
import matplotlib.cm as cm
#!pip install latex

bias_variance_results = pd.read_csv("bias_variance_results.csv")


bias_variance_results.loc[:, "bias_mean"] = -1*bias_variance_results["bias_mean"]
bias_variance_results.loc[:, "variance_mean"] = -1*bias_variance_results["variance_mean"]

bias_results_stats = display_metric(bias_variance_results, metric = 'bias', flag_latex=False,
                                    split_reg_class=False, methods=METHODS_LIST)

summarry_stats_bias = bias_results_stats.loc["avg_rank", :].reset_index()
summarry_stats_bias.loc[:, "exp"] = "bias"
summarry = pd.concat([summarry_accuarcy, summarry_stats_sparss, summarry_stats_bias])
display(summarry.set_index(["model_name", "exp"]).unstack())

variance_results_stats = display_metric(bias_variance_results, metric = 'variance', flag_latex=False,
                                        split_reg_class=False)
plt.rcParams['text.usetex'] = True

fig, ax = plt.subplots(figsize=(8, 8))
x, y, model_names = bias_results_stats.loc["avg_rank"].sort_index().values.astype(float), \
    variance_results_stats.loc["avg_rank"].sort_index().values.astype(float), bias_results_stats.loc["avg_rank"].sort_index().index
colors = cm.rainbow(np.linspace(0, 1, len(x)))

ax.scatter(x, y)

for i, txt in enumerate(model_names):
    if txt in model_name_dict:
        txt = model_name_dict[txt]
    add_y = 0
    add_x = 0.02
    if txt in ["EGB-BF"]:
        add_y = -0.2
    if txt in ["EB$^2$M"]:
        add_x = 0.03
        add_y = -0.1
    if txt in ["EG$^2$B-BF$^2$"]:
        add_y = 0.1
        add_x = -0.02
    if txt == "EG$^2$B":
        add_y = 0.1
        add_x = -0.2
    if txt == "EB$^2$M":
        add_y = -0.3
        
    ax.annotate(txt, (x[i] + add_x * x[i], y[i]+add_y), size=16)

#plt.xlim(2, 8)
plt.xlim(1.5, 10)

plt.legend()
plt.xlabel('Bias Rank', fontsize=20)
plt.ylabel('Variance Rank', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# <style  type="text/css" >
# #T_cfc71_row0_col0,#T_cfc71_row1_col0,#T_cfc71_row2_col6,#T_cfc71_row3_col0,#T_cfc71_row4_col7,#T_cfc71_row5_col1,#T_cfc71_row5_col2,#T_cfc71_row5_col3,#T_cfc71_row5_col4,#T_cfc71_row5_col5,#T_cfc71_row5_col6,#T_cfc71_row5_col7,#T_cfc71_row6_col1,#T_cfc71_row6_col4,#T_cfc71_row6_col5,#T_cfc71_row7_col0,#T_cfc71_row8_col0,#T_cfc71_row9_col0,#T_cfc71_row10_col4,#T_cfc71_row11_col8,#T_cfc71_row12_col8,#T_cfc71_row13_col8,#T_cfc71_row14_col4,#T_cfc71_row15_col7{
#             background-color:  #cd4f39;
#         }#T_cfc71_row0_col7,#T_cfc71_row1_col8,#T_cfc71_row2_col7,#T_cfc71_row3_col7,#T_cfc71_row4_col0,#T_cfc71_row5_col0,#T_cfc71_row6_col7,#T_cfc71_row7_col8,#T_cfc71_row8_col6,#T_cfc71_row8_col8,#T_cfc71_row9_col7,#T_cfc71_row10_col8,#T_cfc71_row11_col4,#T_cfc71_row12_col0,#T_cfc71_row13_col0,#T_cfc71_row14_col7,#T_cfc71_row15_col4{
#             background-color:  lightgreen;
#         }</style><table id="T_cfc71_" ><thead>    <tr>        <th class="index_name level0" >model_name</th>        <th class="col_heading level0 col0" >XGB</th>        <th class="col_heading level0 col1" >EBM_GA2M</th>        <th class="col_heading level0 col2" >EGB_XGB_GA2M_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col3" >EGB_XGB_GA2M_CYCLIC_BEST_FIT</th>        <th class="col_heading level0 col4" >EGB_XGB_GA2M_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col5" >EGB_XGB_GAM_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col6" >EGB_XGB_GAM_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col7" >Spline</th>        <th class="col_heading level0 col8" >EBM_GAM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cfc71_level0_row0" class="row_heading level0 row0" >adult</th>
#                         <td id="T_cfc71_row0_col0" class="data row0 col0" >-0.087±0.00</td>
#                         <td id="T_cfc71_row0_col1" class="data row0 col1" >-0.088±0.00</td>
#                         <td id="T_cfc71_row0_col2" class="data row0 col2" >-0.088±0.00</td>
#                         <td id="T_cfc71_row0_col3" class="data row0 col3" >-0.088±0.00</td>
#                         <td id="T_cfc71_row0_col4" class="data row0 col4" >nan</td>
#                         <td id="T_cfc71_row0_col5" class="data row0 col5" >-0.090±0.00</td>
#                         <td id="T_cfc71_row0_col6" class="data row0 col6" >-0.089±0.00</td>
#                         <td id="T_cfc71_row0_col7" class="data row0 col7" >-0.094±0.00</td>
#                         <td id="T_cfc71_row0_col8" class="data row0 col8" >-0.089±0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_cfc71_level0_row1" class="row_heading level0 row1" >bike</th>
#                         <td id="T_cfc71_row1_col0" class="data row1 col0" >-1560.683±131.45</td>
#                         <td id="T_cfc71_row1_col1" class="data row1 col1" >-2599.380±111.97</td>
#                         <td id="T_cfc71_row1_col2" class="data row1 col2" >-2600.933±112.42</td>
#                         <td id="T_cfc71_row1_col3" class="data row1 col3" >-2607.979±105.18</td>
#                         <td id="T_cfc71_row1_col4" class="data row1 col4" >nan</td>
#                         <td id="T_cfc71_row1_col5" class="data row1 col5" >-9548.828±235.89</td>
#                         <td id="T_cfc71_row1_col6" class="data row1 col6" >-9548.479±239.69</td>
#                         <td id="T_cfc71_row1_col7" class="data row1 col7" >-9547.982±250.16</td>
#                         <td id="T_cfc71_row1_col8" class="data row1 col8" >-9549.036±243.23</td>
#             </tr>
#             <tr>
#                         <th id="T_cfc71_level0_row2" class="row_heading level0 row2" >breast</th>
#                         <td id="T_cfc71_row2_col0" class="data row2 col0" >-0.038±0.01</td>
#                         <td id="T_cfc71_row2_col1" class="data row2 col1" >-0.038±0.01</td>
#                         <td id="T_cfc71_row2_col2" class="data row2 col2" >-0.037±0.01</td>
#                         <td id="T_cfc71_row2_col3" class="data row2 col3" >-0.037±0.01</td>
#                         <td id="T_cfc71_row2_col4" class="data row2 col4" >-0.037±0.02</td>
#                         <td id="T_cfc71_row2_col5" class="data row2 col5" >-0.037±0.02</td>
#                         <td id="T_cfc71_row2_col6" class="data row2 col6" >-0.036±0.01</td>
#                         <td id="T_cfc71_row2_col7" class="data row2 col7" >-0.097±0.01</td>
#                         <td id="T_cfc71_row2_col8" class="data row2 col8" >-0.041±0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_cfc71_level0_row3" class="row_heading level0 row3" >california housing</th>
#                         <td id="T_cfc71_row3_col0" class="data row3 col0" >-0.215±0.01</td>
#                         <td id="T_cfc71_row3_col1" class="data row3 col1" >-0.259±0.01</td>
#                         <td id="T_cfc71_row3_col2" class="data row3 col2" >-0.250±0.01</td>
#                         <td id="T_cfc71_row3_col3" class="data row3 col3" >-0.245±0.01</td>
#                         <td id="T_cfc71_row3_col4" class="data row3 col4" >-0.244±0.01</td>
#                         <td id="T_cfc71_row3_col5" class="data row3 col5" >-0.326±0.01</td>
#                         <td id="T_cfc71_row3_col6" class="data row3 col6" >-0.330±0.01</td>
#                         <td id="T_cfc71_row3_col7" class="data row3 col7" >-0.358±0.01</td>
#                         <td id="T_cfc71_row3_col8" class="data row3 col8" >-0.328±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_cfc71_level0_row4" class="row_heading level0 row4" >churn</th>
#                         <td id="T_cfc71_row4_col0" class="data row4 col0" >-0.138±0.01</td>
#                         <td id="T_cfc71_row4_col1" class="data row4 col1" >-0.136±0.01</td>
#                         <td id="T_cfc71_row4_col2" class="data row4 col2" >-0.136±0.01</td>
#                         <td id="T_cfc71_row4_col3" class="data row4 col3" >-0.136±0.01</td>
#                         <td id="T_cfc71_row4_col4" class="data row4 col4" >nan</td>
#                         <td id="T_cfc71_row4_col5" class="data row4 col5" >-0.136±0.01</td>
#                         <td id="T_cfc71_row4_col6" class="data row4 col6" >-0.136±0.01</td>
#                         <td id="T_cfc71_row4_col7" class="data row4 col7" >-0.135±0.01</td>
#                         <td id="T_cfc71_row4_col8" class="data row4 col8" >-0.136±0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_cfc71_level0_row5" class="row_heading level0 row5" >compas</th>
#                         <td id="T_cfc71_row5_col0" class="data row5 col0" >-0.207±0.00</td>
#                         <td id="T_cfc71_row5_col1" class="data row5 col1" >-0.204±0.00</td>
#                         <td id="T_cfc71_row5_col2" class="data row5 col2" >-0.204±0.00</td>
#                         <td id="T_cfc71_row5_col3" class="data row5 col3" >-0.204±0.00</td>
#                         <td id="T_cfc71_row5_col4" class="data row5 col4" >-0.204±0.00</td>
#                         <td id="T_cfc71_row5_col5" class="data row5 col5" >-0.204±0.00</td>
#                         <td id="T_cfc71_row5_col6" class="data row5 col6" >-0.204±0.00</td>
#                         <td id="T_cfc71_row5_col7" class="data row5 col7" >-0.204±0.00</td>
#                         <td id="T_cfc71_row5_col8" class="data row5 col8" >-0.205±0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_cfc71_level0_row6" class="row_heading level0 row6" >crimes</th>
#                         <td id="T_cfc71_row6_col0" class="data row6 col0" >-0.019±0.00</td>
#                         <td id="T_cfc71_row6_col1" class="data row6 col1" >-0.018±0.00</td>
#                         <td id="T_cfc71_row6_col2" class="data row6 col2" >-0.019±0.00</td>
#                         <td id="T_cfc71_row6_col3" class="data row6 col3" >-0.019±0.00</td>
#                         <td id="T_cfc71_row6_col4" class="data row6
#                                avg_rank
# exp                            accuracy  bias feature_sparsness
# model_name
# EBM_GA2M                           2.10  3.60              2.15
# EBM_GAM                            3.30  7.05              5.30
# EGB_XGB_GA2M_BEST_FIT_BEST_FIT     6.05  5.20              5.10
# EGB_XGB_GA2M_CYCLIC_BEST_FIT       5.65  4.15              3.00
# EGB_XGB_GA2M_CYCLIC_CYCLIC         5.10  3.90              2.70
# EGB_XGB_GAM_BEST_FIT_BEST_FIT       NaN  5.20              7.25
# EGB_XGB_GAM_CYCLIC_CYCLIC           NaN  5.65              5.55
# Spline                             3.65  6.70              4.95
# XGB                                2.15  3.55               NaN
# <style  type="text/css" >
# #T_73cdd_row0_col0,#T_73cdd_row0_col1,#T_73cdd_row0_col2,#T_73cdd_row0_col3,#T_73cdd_row0_col4,#T_73cdd_row0_col5,#T_73cdd_row0_col6,#T_73cdd_row1_col3,#T_73cdd_row2_col3,#T_73cdd_row2_col5,#T_73cdd_row2_col6,#T_73cdd_row3_col0,#T_73cdd_row4_col0,#T_73cdd_row4_col1,#T_73cdd_row4_col2,#T_73cdd_row4_col3,#T_73cdd_row4_col4,#T_73cdd_row4_col5,#T_73cdd_row4_col6,#T_73cdd_row5_col0,#T_73cdd_row5_col1,#T_73cdd_row5_col2,#T_73cdd_row5_col3,#T_73cdd_row6_col0,#T_73cdd_row6_col1,#T_73cdd_row6_col2,#T_73cdd_row6_col7,#T_73cdd_row7_col0,#T_73cdd_row8_col0,#T_73cdd_row8_col1,#T_73cdd_row8_col2,#T_73cdd_row9_col0,#T_73cdd_row9_col1,#T_73cdd_row10_col7,#T_73cdd_row11_col8,#T_73cdd_row12_col8,#T_73cdd_row13_col8,#T_73cdd_row14_col0,#T_73cdd_row15_col8{
#             background-color:  #cd4f39;
#         }#T_73cdd_row0_col8,#T_73cdd_row1_col8,#T_73cdd_row2_col8,#T_73cdd_row3_col8,#T_73cdd_row4_col8,#T_73cdd_row5_col8,#T_73cdd_row6_col8,#T_73cdd_row7_col8,#T_73cdd_row8_col8,#T_73cdd_row9_col3,#T_73cdd_row10_col8,#T_73cdd_row11_col7,#T_73cdd_row12_col0,#T_73cdd_row13_col0,#T_73cdd_row14_col8,#T_73cdd_row15_col0{
#             background-color:  lightgreen;
#         }</style><table id="T_73cdd_" ><thead>    <tr>        <th class="index_name level0" >model_name</th>        <th class="col_heading level0 col0" >EGB_XGB_GAM_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col1" >EBM_GAM</th>        <th class="col_heading level0 col2" >EGB_XGB_GAM_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col3" >Spline</th>        <th class="col_heading level0 col4" >EBM_GA2M</th>        <th class="col_heading level0 col5" >EGB_XGB_GA2M_CYCLIC_CYCLIC</th>        <th class="col_heading level0 col6" >EGB_XGB_GA2M_CYCLIC_BEST_FIT</th>        <th class="col_heading level0 col7" >EGB_XGB_GA2M_BEST_FIT_BEST_FIT</th>        <th class="col_heading level0 col8" >XGB</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73cdd_level0_row0" class="row_heading level0 row0" >adult</th>
#                         <td id="T_73cdd_row0_col0" class="data row0 col0" >-0.001±0.00</td>
#                         <td id="T_73cdd_row0_col1" class="data row0 col1" >-0.001±0.00</td>
#                         <td id="T_73cdd_row0_col2" class="data row0 col2" >-0.001±0.00</td>
#                         <td id="T_73cdd_row0_col3" class="data row0 col3" >-0.001±0.00</td>
#                         <td id="T_73cdd_row0_col4" class="data row0 col4" >-0.001±0.00</td>
#                         <td id="T_73cdd_row0_col5" class="data row0 col5" >-0.001±0.00</td>
#                         <td id="T_73cdd_row0_col6" class="data row0 col6" >-0.001±0.00</td>
#                         <td id="T_73cdd_row0_col7" class="data row0 col7" >nan</td>
#                         <td id="T_73cdd_row0_col8" class="data row0 col8" >-0.003±0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_73cdd_level0_row1" class="row_heading level0 row1" >bike</th>
#                         <td id="T_73cdd_row1_col0" class="data row1 col0" >-66.644±5.84</td>
#                         <td id="T_73cdd_row1_col1" class="data row1 col1" >-77.938±5.63</td>
#                         <td id="T_73cdd_row1_col2" class="data row1 col2" >-81.313±4.24</td>
#                         <td id="T_73cdd_row1_col3" class="data row1 col3" >-60.572±4.78</td>
#                         <td id="T_73cdd_row1_col4" class="data row1 col4" >-145.895±8.97</td>
#                         <td id="T_73cdd_row1_col5" class="data row1 col5" >-166.577±14.38</td>
#                         <td id="T_73cdd_row1_col6" class="data row1 col6" >-179.613±15.89</td>
#                         <td id="T_73cdd_row1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_73cdd_row1_col8" class="data row1 col8" >-268.593±10.70</td>
#             </tr>
#             <tr>
#                         <th id="T_73cdd_level0_row2" class="row_heading level0 row2" >breast</th>
#                         <td id="T_73cdd_row2_col0" class="data row2 col0" >-0.002±0.00</td>
#                         <td id="T_73cdd_row2_col1" class="data row2 col1" >-0.004±0.00</td>
#                         <td id="T_73cdd_row2_col2" class="data row2 col2" >-0.002±0.00</td>
#                         <td id="T_73cdd_row2_col3" class="data row2 col3" >-0.001±0.00</td>
#                         <td id="T_73cdd_row2_col4" class="data row2 col4" >-0.007±0.00</td>
#                         <td id="T_73cdd_row2_col5" class="data row2 col5" >-0.001±0.00</td>
#                         <td id="T_73cdd_row2_col6" class="data row2 col6" >-0.001±0.00</td>
#                         <td id="T_73cdd_row2_col7" class="data row2 col7" >-0.002±0.00</td>
#                         <td id="T_73cdd_row2_col8" class="data row2 col8" >-0.009±0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_73cdd_level0_row3" class="row_heading level0 row3" >california housing</th>
#                         <td id="T_73cdd_row3_col0" class="data row3 col0" >-0.006±0.00</td>
#                         <td id="T_73cdd_row3_col1" class="data row3 col1" >-0.008±0.00</td>
#                         <td id="T_73cdd_row3_col2" class="data row3 col2" >-0.008±0.00</td>
#                         <td id="T_73cdd_row3_col3" class="data row3 col3" >-0.007±0.01</td>
#                         <td id="T_73cdd_row3_col4" class="data row3 col4" >-0.016±0.00</td>
#                         <td id="T_73cdd_row3_col5" class="data row3 col5" >-0.020±0.00</td>
#                         <td id="T_73cdd_row3_col6" class="data row3 col6" >-0.019±0.00</td>
#                         <td id="T_73cdd_row3_col7" class="data row3 col7" >-0.020±0.00</td>
#                         <td id="T_73cdd_row3_col8" class="data row3 col8" >-0.026±0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_73cdd_level0_row4" class="row_heading level0 row4" >churn</th>
#                         <td id="T_73cdd_row4_col0" class="data row4 col0" >-0.001±0.00</td>
#                         <td id="T_73cdd_row4_col1" class="data row4 col1" >-0.001±0.00</td>
#                         <td id="T_73cdd_row4_col2" class="data row4 col2" >-0.001±0.00</td>
#                         <td id="T_73cdd_row4_col3" class="data row4 col3" >-0.001±0.00</td>
#                         <td id="T_73cdd_row4_col4" class="data row4 col4" >-0.001±0.00</td>
#                         <td id="T_73cdd_row4_col5" class="data row4 col5" >-0.001±0.00</td>
#                         <td id="T_73cdd_row4_col6" class="data row4 col6" >-0.001±0.00</td>
#                         <td id="T_73cdd_row4_col7" class="data row4 col7" >nan</td>
#                         <td id="T_73cdd_row4_col8" class="data row4 col8" >-0.006±0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_73cdd_level0_row5" class="row_heading level0 row5" >compas</th>
#                         <td id="T_73cdd_row5_col0" class="data row5 col0" >-0.000±0.00</td>
#                         <td id="T_73cdd_row5_col1" class="data row5 col1" >-0.000±0.00</td>
#                         <td id="T_73cdd_row5_col2" class="data row5 col2" >-0.000±0.00</td>
#                         <td id="T_73cdd_row5_col3" class="data row5 col3" >-0.000±0.00</td>
#                         <td id="T_73cdd_row5_col4" class="data row5 col4" >-0.001±0.00</td>
#                         <td id="T_73cdd_row5_col5" class="data row5 col5" >-0.001±0.00</td>
#                         <td id="T_73cdd_row5_col6" class="data row5 col6" >-0.001±0.00</td>
#                         <td id="T_73cdd_row5_col7" class="data row5 col7" >-0.001±0.00</td>
#                         <td id="T_73cdd_row5_col8" class="data row5 col8" >-0.005±0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_73cdd_level0_row6" class="row_heading level0 row6" >crimes</th>
#                         <td id="T_73cdd_row6_col0" class="data row6 col0" >-0.000±0.00</td>
#                         <td id="T_73cdd_row6_col1" class="data row6 col1" >-0.000±0.00</td>
# (array([2., 3., 4., 5., 6., 7., 8., 9.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
